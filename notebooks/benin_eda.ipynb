# %% [markdown]
# # Solar Data EDA - Benin
# **Branch:** `eda-benin`
# **Objective:** Clean and profile solar dataset for regional ranking
# **Key Files:**
# - Input: `data/benin-malanville.csv` (gitignored)
# - Output: `data/clean/benin_clean.csv` (gitignored)

# %% [markdown]
# ### 1. Setup and Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

benin_df = pd.read_csv('../data/sierraleone-bumbuna.csv', parse_dates=['Timestamp'])

print(f"Benin solar data shape: {benin_df.shape}")
print(f"Benin solar data szie: {benin_df.size}")
print(f"Benin solar data columns: {benin_df.columns}")
print(benin_df.head())
# Out:
# Benin solar data shape: (525600, 19)
# Benin solar data szie: 9986400
# Benin solar data columns: Index(['Timestamp', 'GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS',
#        'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation',
#        'TModA', 'TModB', 'Comments'],
#       dtype='object')
#             Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0 2021-10-30 00:01:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1 2021-10-30 00:02:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2 2021-10-30 00:03:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3 2021-10-30 00:04:00 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4 2021-10-30 00:05:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# ...

# %% [markdown]
# ### 2. describe the data to get the benin solar data stats details

# %%
benin_df.describe()
# Out:
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-04-30 12:00:30.000000768     201.957515     116.376337
# min              2021-10-30 00:01:00     -19.500000      -7.800000
# 25%              2022-01-29 06:00:45      -2.800000      -0.300000
# 50%              2022-04-30 12:00:30       0.300000      -0.100000
# 75%              2022-07-30 18:00:15     362.400000     107.000000
# max              2022-10-30 00:00:00    1499.000000     946.000000
# std                              NaN     298.495150     218.652659
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      113.720571     206.643095     198.114691      26.319394
# min       -17.900000       0.000000       0.000000      12.300000
# 25%        -3.800000       0.000000       0.000000      23.100000
# ...

# %% [markdown]
# ### 3. benin solar data info

# %%
benin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  datetime64[ns]
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
# ...

# %% [markdown]
# ### 4. Check for duplicate timestamps

# %%
dup_timestamps = benin_df[benin_df.duplicated(subset=['Timestamp'], keep=False)]
print(f"Duplicate timestamps: {dup_timestamps}")
# Out:
# Duplicate timestamps: Empty DataFrame
# Columns: [Timestamp, GHI, DNI, DHI, ModA, ModB, Tamb, RH, WS, WSgust, WSstdev, WD, WDstdev, BP, Cleaning, Precipitation, TModA, TModB, Comments]
# Index: []

# %% [markdown]
# ### 5. No duplicate, so use timestamp as index

# %%
benin_df.set_index('Timestamp', inplace=True)
print(benin_df.head())
# Out:
#                      GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# Timestamp
# 2021-10-30 00:01:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 2021-10-30 00:02:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2021-10-30 00:03:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2021-10-30 00:04:00 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 2021-10-30 00:05:00 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#                      WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  \
# Timestamp
# 2021-10-30 00:01:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:02:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:03:00      0.0  0.0      0.0  1002         0            0.0
# 2021-10-30 00:04:00      0.0  0.0      0.0  1002         0            0.1
# 2021-10-30 00:05:00      0.0  0.0      0.0  1002         0            0.0
#
#                      TModA  TModB  Comments
# Timestamp
# ...

# %% [markdown]
# #### 6. Missing data report

# %%
missing = benin_df.isna().sum()

print(f"Missing values: {missing}")
threshold = 0.05 * len(benin_df)
print(f"threshold", threshold)
print("Columns with >5% missing values:\n", missing[missing > threshold])
# Out:
# Missing values: GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
# threshold 26280.0
# Columns with >5% missing values:
#  Comments    525600
# dtype: int64

# %% [markdown]
# ### 7.  Z-scores

# %%
cols_to_check = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
z_scores   = np.abs(zscore(df[cols_to_check].dropna()))
print(f"z_scores: {z_scores}")
# Out:
# z_scores:              GHI       DNI       DHI      ModA      ModB        WS    WSgust
# 0       0.678931  0.532701  0.720500  0.686758  0.685782  0.924846  1.046105
# 1       0.678931  0.532701  0.720500  0.686758  0.685782  0.924846  1.046105
# 2       0.678931  0.532701  0.720500  0.686758  0.685782  0.924846  1.046105
# 3       0.678931  0.532243  0.720500  0.686758  0.685782  0.924846  1.046105
# 4       0.678931  0.532701  0.720500  0.686758  0.685782  0.924846  1.046105
# ...          ...       ...       ...       ...       ...       ...       ...
# 525595  0.681946  0.532701  0.733712  0.686758  0.685782  0.924846  1.046105
# 525596  0.682281  0.532701  0.734342  0.686758  0.685782  0.924846  1.046105
# 525597  0.682281  0.532701  0.734971  0.686758  0.685782  0.924846  1.046105
# 525598  0.682281  0.533158  0.736229  0.686758  0.685782  0.924846  1.046105
# 525599  0.682281  0.532701  0.736858  0.686758  0.685782  0.924846  1.046105
#
# [525600 rows x 7 columns]

# %% [markdown]
# ### 8. Outliers detection

# %%
outliers = (z_scores > 3).any(axis=1)
benin_df['CleaningFlag'] = outliers
print(f"outliers: {outliers}")
print(benin_df["CleaningFlag"].value_counts())
outlier_rows = benin_df[benin_df['CleaningFlag']]
outlier_rows.head()
# Out:
# outliers: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 525595    False
# 525596    False
# 525597    False
# 525598    False
# 525599    False
# Length: 525600, dtype: bool
# CleaningFlag
# False    509308
# True      16292
# Name: count, dtype: int64
#               Timestamp    GHI    DNI    DHI   ModA   ModB  Tamb    RH   WS  \
# 653 2021-10-30 10:54:00  814.0  257.0  594.3  878.0  856.0  25.9  85.3  0.5
# 654 2021-10-30 10:55:00  826.0  263.5  599.6  883.0  861.0  26.0  85.4  1.7
# 655 2021-10-30 10:56:00  851.0  285.0  605.9  912.0  890.0  26.0  84.2  1.6
# 656 2021-10-30 10:57:00  823.0  254.8  603.9  878.0  856.0  26.0  85.3  0.8
# 657 2021-10-30 10:58:00  810.0  244.5  598.8  864.0  843.0  26.1  85.7  0.6
#
#      WSgust  WSstdev     WD  WDstdev    BP  Cleaning  Precipitation  TModA  \
# 653     1.1      0.5   81.4      7.9  1002         0            0.0   50.4
# ...

# %% [markdown]
# #### 9. Impute and clean

# %%
benin_clean = benin_df.copy()
benin_clean[cols_to_check] = benin_clean[cols_to_check].fillna(benin_clean[cols_to_check].mean())
benin_clean.head
# Out:
# <bound method NDFrame.head of                  Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  \
# 0      2021-10-30 00:01:00 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.1  0.0
# 1      2021-10-30 00:02:00 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0
# 2      2021-10-30 00:03:00 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0
# 3      2021-10-30 00:04:00 -0.7  0.0 -0.8   0.0   0.0  21.9   99.3  0.0
# 4      2021-10-30 00:05:00 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.3  0.0
# ...                    ...  ...  ...  ...   ...   ...   ...    ...  ...
# 525595 2022-10-29 23:56:00 -1.6 -0.1 -2.9   0.0   0.0  24.0  100.0  0.0
# 525596 2022-10-29 23:57:00 -1.7 -0.1 -3.0   0.0   0.0  24.0  100.0  0.0
# 525597 2022-10-29 23:58:00 -1.7 -0.1 -3.1   0.0   0.0  24.0  100.0  0.0
# 525598 2022-10-29 23:59:00 -1.7 -0.2 -3.3   0.0   0.0  23.9  100.0  0.0
# 525599 2022-10-30 00:00:00 -1.7 -0.1 -3.4   0.0   0.0  23.9  100.0  0.0
#
# ...

# %% [markdown]
# ### 10. save or export clean data

# %%
benin_clean.to_csv('../data/clean/benin_clean.csv', index=False)

# %% [markdown]
# ### 11. Time Series Analysis

# %%
flg, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
benin_clean[['GHI']].plot(ax=axs[0,0], title="GHI over Time")
benin_clean[['DNI']].plot(ax=axs[0,1], title="DNI over Time")
benin_clean[['DHI']].plot(ax=axs[1,0], title="DHI over Time")
benin_clean[['Tamb']].plot(ax=axs[1,1], title="Tamb over Time")
plt.tight_layout()

# %% [markdown]
# ### 12 . cleaning effect

# %%
benin_df.groupby('CleaningFlag')[['ModA', 'ModB']].mean().plot(kind='bar', title="ModA & ModB: Clean vs Dirty", figsize=(8,5))
# Out:
# <Axes: title={'center': 'ModA & ModB: Clean vs Dirty'}, xlabel='CleaningFlag'>

# %% [markdown]
# #### 13. Correlation Heatmap

# %%
heat_cols = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
sns.heatmap(benin_clean[heat_cols].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### 14. Scater plot

# %%
sns.scatterplot(data=benin_clean, x='WS', y='GHI')
sns.scatterplot(data=benin_clean, x='WSgust', y='GHI')
sns.scatterplot(data=benin_clean, x='WD', y='GHI')
sns.scatterplot(data=benin_clean, x='RH', y='Tamb')
sns.scatterplot(data=benin_clean, x='RH', y='GHI')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %% [markdown]
# #### 15. Wind & Temperature Analysis

# %%
# Simple radial histogram (if no wind rose lib available)
benin_clean['WD_bin'] = pd.cut(benin_clean['WD'], bins=np.arange(0, 370, 30))
wind_dist = benin_clean.groupby('WD_bin', observed=True)['WS'].mean()


wind_dist.plot(kind='bar', title='Average Wind Speed by Direction Bin')
# Out:
# <Axes: title={'center': 'Average Wind Speed by Direction Bin'}, xlabel='WD_bin'>

# %% [markdown]
# Histograms for GHI and one other variable (e.g. WS).

# %%
benin_clean['GHI'].hist(bins=30, alpha=0.7)
plt.title("Histogram of GHI")

benin_clean['WS'].hist(bins=30, alpha=0.7)
plt.title("Histogram of Wind Speed")
# Out:
# Text(0.5, 1.0, 'Histogram of Wind Speed')

# %%
sns.lmplot(data=benin_clean, x='RH', y='Tamb', height=5, aspect=1.5)
sns.lmplot(data=benin_clean, x='RH', y='GHI', height=5, aspect=1.5)

# %% [markdown]
# Bubble chart

# %%
plt.figure(figsize=(10,6))
plt.scatter(benin_clean['GHI'], benin_clean['Tamb'], s=benin_clean['RH'], alpha=0.5, label="RH as Bubble Size")
plt.xlabel("GHI")
plt.ylabel("Tamb")
plt.title("GHI vs Tamb with RH as Bubble Size")
# Out:
# Text(0.5, 1.0, 'GHI vs Tamb with RH as Bubble Size')
